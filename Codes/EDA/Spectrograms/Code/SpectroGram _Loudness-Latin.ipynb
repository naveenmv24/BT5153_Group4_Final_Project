# %%
import pandas as pd
import numpy as np
import hdf5_getters as hd
import glob
import sklearn
from sklearn import preprocessing

# %%
#To see if all the 10,000 files are available for data extraction
h5_dir = "MillionSongSubset" #<file_path where the song_dataset is stored>

# Get a list of all .h5 files in the directory and its subdirectories
h5_files = glob.glob(h5_dir + '/**/*.h5', recursive=True)
len(h5_files) #should be 10,000
# Out:
# 10000

# %%
#Reading the dataset
df = pd.read_csv("3593_song_newfeatures_genre_dataset.csv")

# %%
#Filtering out data for Latin genre 
df_song = df[df['genre'] == 'Latin']
df_song
# Out:
#       Unnamed: 0                  id  spectral_centroid_mean  \
# 28            28  TRBGFAX128F4275F56                   8.034
# 44            44  TRBGNAF128F9339532                  15.980
# 53            53  TRBGTNZ128F1481BBD                   7.546
# 54            54  TRBGTAB12903CF8B83                   7.670
# 58            58  TRBGUUF128F9334B97                   6.497
# ...          ...                 ...                     ...
# 3511        3511  TRAYFIV128F429E381                   4.685
# 3539        3539  TRAYTMR128F92FF07C                   8.311
# 3567        3567  TRAYSUA128F9338AD8                   4.133
# 3580        3580  TRAYXZX128F930F022                  11.980
# 3589        3589  TRAYYGS128F1495E48                   7.984
#
#       spectral_centroid_dev  rolloff_point_mean  rolloff_point_dev  flux_mean  \
# 28                    7.450             0.05068            0.06866   0.002834
# 44                    7.398             0.10360            0.05462   0.004212
# 53                    3.935             0.04586            0.03187   0.000665
# 54                    6.284             0.05077            0.04878   0.000232
# 58                    7.147             0.04139            0.05374   0.002756
# ...                     ...                 ...                ...        ...
# 3511                  4.117             0.02866            0.03662   0.001631
# 3539                  6.013             0.05356            0.05184   0.002502
# 3567                  7.669             0.02416            0.05537   0.000496
# 3580                 12.000             0.07340            0.09852   0.002881
# 3589                  3.961             0.04837            0.03057   0.000610
#
#       flux_dev  variability_mean  variability_dev  compactness_mean  \
# 28    0.006505          0.003650         0.002485            1703.0
# 44    0.006810          0.005159         0.002491            1566.0
# 53    0.000835          0.002938         0.001415            1757.0
# 54    0.000268          0.001754         0.000776            1714.0
# 58    0.004007          0.004893         0.002855            1639.0
# ...        ...               ...              ...               ...
# 3511  0.002603          0.003622         0.001917            1780.0
# 3539  0.005240          0.004454         0.002555            1720.0
# 3567  0.000691          0.002472         0.001264            1634.0
# 3580  0.005143          0.006046         0.003322            1646.0
# 3589  0.000827          0.002480         0.001289            1707.0
#
#       compactness_dev  rms_mean  rms_dev  low_energy_window_mean  \
# 28              239.9   0.14080  0.08146                  0.5890
# 44              170.0   0.20630  0.09007                  0.6375
# 53              224.3   0.11190  0.05187                  0.5635
# 54              273.7   0.06729  0.02964                  0.5098
# 58              229.6   0.18200  0.10030                  0.5186
# ...               ...       ...      ...                     ...
# 3511            232.0   0.13610  0.06593                  0.5486
# 3539            304.4   0.17070  0.08882                  0.5848
# 3567            173.2   0.09038  0.04304                  0.4820
# 3580            207.9   0.22980  0.11870                  0.4976
# 3589            255.6   0.09613  0.04739                  0.5102
#
#       low_energy_window_dev  zero_crossing_mean  zero_crossing_dev  \
# 28                  0.05763               29.52              19.90
# 44                  0.07176               42.82              16.20
# 53                  0.06972               21.32              10.57
# 54                  0.07529               20.71              15.51
# 58                  0.04493               19.75              16.96
# ...                     ...                 ...                ...
# 3511                0.07083               14.61              11.66
# 3539                0.05475               25.02              16.00
# 3567                0.06108               13.10              17.70
# 3580                0.08025               36.33              28.08
# 3589                0.05906               21.26              10.09
#
#                                         title  genre
# 28                          b'La Bruja Chafa'  Latin
# 44                            b'Noche De Paz'  Latin
# 53                                b'Palavras'  Latin
# 54                               b'Accept Me'  Latin
# 58                           b'No Hay Manera'  Latin
# ...                                       ...    ...
# 3511                       b'Momento De Amor'  Latin
# 3539                                b'Andale'  Latin
# 3567                      b'Amor De Juventud'  Latin
# 3580                          b'Nunca Sabras'  Latin
# 3589  b'Guarare (Live At The Beacon Theatre)'  Latin
#
# [256 rows x 20 columns]

# %%
#Creating lists of Genre and Track_id
track_id = df_song['id'].tolist()
genre = df_song['genre'].tolist()

# %%
genre
# Out:
# ['Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin']

# %%
#Function to extract the cleaned track_id
def clean(text):
    text = str(text)
    text = text.replace("b'", "")
    text = text[:-1]
    return text

# %%
#Collecting segment info for Loudness only for those songs in the 3953_dataset
batch_size = 10

song_id = []
loud_max_seg = []
pitch_seg = []
timbre_seg = []

for i in range(0, len(h5_files), batch_size):
    # Get the batch of files
    batch_files = h5_files[i:i+batch_size]
    
    # Loop through the files in the batch
    for file_name in batch_files:
        h5 = hd.open_h5_file_read(file_name)
        
        id = hd.get_track_id(h5)
        id = clean(id)

        if id in track_id:
            #print("Collecting data")
            song_id.append(hd.get_track_id(h5))
            loud_max_seg.append(hd.get_segments_loudness_max(h5))
            timbre_seg.append(hd.get_segments_timbre(h5))
            pitch_seg.append(hd.get_segments_pitches(h5))
        
        h5.close()

# %%
#All are equal to the number of songs filtered out from the Latin genre
len(song_id), len(loud_max_seg), len(timbre_seg), len(pitch_seg), len(genre)
# Out:
# (256, 256, 256, 256, 256)

# %%
#Inspecting values of loudness for different segments for 2 songs.
loud_max_seg[0:2]
# Out:
# [array([-17.012, -20.43 , -20.447, ..., -23.158,  -8.142,  -5.442]),
#  array([-56.402, -27.409, -30.953, -27.553, -27.522, -26.5  , -27.037,
#         -27.817, -24.432, -23.634, -24.221, -23.268, -24.07 , -21.605,
#         -23.437, -22.31 , -22.015, -21.415, -22.483, -21.021, -21.876,
#         -21.357, -20.818, -19.16 , -23.665, -24.66 , -22.427, -23.758,
#         -21.492, -24.149, -19.256, -16.56 , -18.209, -14.903, -19.17 ,
#         -17.154, -19.537, -20.723, -25.706, -20.392, -32.132, -27.796,
#         -20.908, -27.996, -31.909, -26.695, -28.971, -21.22 , -32.702,
#         -26.189, -34.216, -27.352, -26.032, -24.419, -24.116, -26.784,
#         -25.261, -20.869, -28.888, -25.46 , -29.706, -22.636, -26.014,
#         -19.62 , -23.937, -20.586, -24.757, -24.445, -21.67 , -20.501,
#         -21.709, -18.232, -35.916, -19.594, -22.365, -24.466, -25.688,
#         -21.061, -22.983, -25.961, -23.996, -19.879, -24.715, -20.197,
#         -19.518, -19.38 , -19.776, -19.891, -20.481, -23.275, -20.078,
#         -23.786, -22.018, -21.39 , -37.859, -24.501, -21.837, -19.715,
#         -21.22 , -19.405, -18.678, -22.8  , -22.384, -19.588, -25.757,
#         -24.847, -20.857, -20.934, -17.858, -21.242, -22.789, -21.725,
#         -22.989, -18.999, -23.128, -23.138, -28.017, -26.081, -23.515,
#         -18.478, -15.64 , -17.614, -21.268, -18.828, -22.474, -20.692,
#         -30.081, -18.855, -25.557, -21.847, -32.773, -26.255, -24.177,
#         -23.899, -23.641, -18.483, -24.273, -23.656, -22.636, -23.09 ,
#         -19.298, -23.847, -21.992, -21.582, -18.349, -21.951, -21.899,
#         -17.165, -19.568, -16.708, -14.307, -14.177, -15.63 , -16.496,
#         -15.05 , -14.7  , -18.229, -13.161, -13.604, -11.767, -12.667,
#         -12.949, -11.67 , -14.67 , -14.597, -11.124, -11.06 , -14.742,
#         -17.468, -12.398, -11.447, -12.134, -12.499, -12.782, -15.402,
#         -14.002, -12.485, -13.099, -10.833, -12.032, -14.347, -16.02 ,
#         -11.323, -17.736, -16.894, -13.552, -15.202, -15.551, -13.973,
#         -15.113, -14.446, -17.972, -16.386, -14.945, -13.566, -12.126,
#         -13.537, -13.267, -13.808, -14.111, -13.104, -13.904, -13.683,
#         -15.564, -13.354, -15.553, -14.897, -14.706, -16.749, -15.812,
#         -19.588, -19.362, -14.851, -17.82 , -17.526, -18.022, -16.269,
#         -15.6  , -14.473, -15.553, -12.356, -15.682, -16.986, -14.809,
#         -11.418, -14.109, -17.222, -20.268, -17.505, -12.755, -13.502,
#         -12.858, -15.293, -14.121, -13.742, -13.732, -11.885, -12.874,
#         -12.655, -11.325, -12.576, -11.996, -15.102, -14.148, -13.131,
#         -10.423, -13.619, -12.986, -15.196, -12.361, -16.441, -17.211,
#         -14.505, -16.018, -14.151, -15.397, -16.081, -13.291, -12.727,
#         -12.026, -16.817, -14.38 , -11.904, -13.45 , -11.477, -14.286,
#         -14.612, -12.537, -14.748, -11.749, -14.281, -17.533, -15.148,
#         -13.015, -11.588, -16.895, -15.895, -13.946, -12.198, -12.279,
#         -11.591, -14.091, -16.828, -13.613, -13.722, -13.034, -14.509,
#         -16.886, -16.278, -15.638, -13.495, -16.644, -18.278, -18.206,
#         -20.568, -16.169, -17.1  , -22.469, -18.968, -36.608, -34.988,
#         -25.715, -35.822, -31.864, -24.119, -22.551, -15.663, -16.327,
#         -14.932, -16.433, -29.113, -19.913, -20.246, -19.599, -19.59 ,
#         -21.194, -16.639, -17.341, -18.973, -17.195, -45.459])]

# %%
#inspecting the segments' shape for all songs
for arr in loud_max_seg:
    print(arr.shape)
# Out:
# (1469,)
# (622,)
# (1268,)
# (353,)
# (1121,)
# (492,)
# (548,)
# (1102,)
# (677,)
# (756,)
# (838,)
# (1045,)
# (904,)
# (1222,)
# (745,)
# (646,)
# (1193,)
# (630,)
# (683,)
# (597,)
# (1503,)
# (937,)
# (606,)
# (1040,)
# (228,)
# (773,)
# (1199,)
# (967,)
# (1688,)
# (695,)
# (2563,)
# (785,)
# (617,)
# (1044,)
# (944,)
# (603,)
# (665,)
# (725,)
# (714,)
# (983,)
# (1001,)
# (1188,)
# (1033,)
# (601,)
# (1476,)
# (576,)
# (340,)
# (853,)
# (599,)
# (576,)
# (1098,)
# (559,)
# (148,)
# (903,)
# (831,)
# (798,)
# (899,)
# (990,)
# (664,)
# (820,)
# (443,)
# (987,)
# (796,)
# (1022,)
# (756,)
# (1449,)
# (1061,)
# (813,)
# (616,)
# (868,)
# (724,)
# (609,)
# (807,)
# (883,)
# (1570,)
# (861,)
# (973,)
# (605,)
# (986,)
# (1254,)
# (1135,)
# (650,)
# (811,)
# (3940,)
# (822,)
# (901,)
# (1044,)
# (896,)
# (481,)
# (794,)
# (404,)
# (744,)
# (726,)
# (700,)
# (967,)
# (575,)
# (1061,)
# (487,)
# (122,)
# (950,)
# (402,)
# (752,)
# (734,)
# (984,)
# (1159,)
# (1080,)
# (917,)
# (847,)
# (969,)
# (803,)
# (1688,)
# (710,)
# (1140,)
# (933,)
# (1084,)
# (459,)
# (597,)
# (1099,)
# (965,)
# (1011,)
# (1979,)
# (755,)
# (501,)
# (495,)
# (1660,)
# (743,)
# (680,)
# (114,)
# (1052,)
# (1451,)
# (743,)
# (453,)
# (1208,)
# (920,)
# (536,)
# (244,)
# (609,)
# (605,)
# (1290,)
# (458,)
# (617,)
# (468,)
# (1155,)
# (1379,)
# (883,)
# (792,)
# (1726,)
# (545,)
# (421,)
# (474,)
# (960,)
# (1355,)
# (747,)
# (1164,)
# (774,)
# (700,)
# (561,)
# (605,)
# (985,)
# (1377,)
# (399,)
# (1247,)
# (498,)
# (797,)
# (958,)
# (839,)
# (844,)
# (994,)
# (707,)
# (1056,)
# (831,)
# (568,)
# (2324,)
# (714,)
# (739,)
# (1270,)
# (865,)
# (1481,)
# (739,)
# (1162,)
# (1364,)
# (852,)
# (944,)
# (816,)
# (998,)
# (365,)
# (806,)
# (798,)
# (439,)
# (614,)
# (561,)
# (917,)
# (764,)
# (712,)
# (2236,)
# (572,)
# (993,)
# (1536,)
# (1647,)
# (1027,)
# (814,)
# (1499,)
# (1032,)
# (821,)
# (748,)
# (734,)
# (1165,)
# (376,)
# (569,)
# (1042,)
# (630,)
# (704,)
# (778,)
# (798,)
# (866,)
# (160,)
# (622,)
# (873,)
# (880,)
# (1248,)
# (728,)
# (1176,)
# (644,)
# (1189,)
# (1040,)
# (5,)
# (1340,)
# (764,)
# (879,)
# (902,)
# (950,)
# (491,)
# (854,)
# (642,)
# (939,)
# (2119,)
# (749,)
# (539,)
# (658,)
# (755,)
# (997,)
# (1165,)
# (796,)
# (931,)
# (442,)
# (540,)
# (798,)
# (1246,)
# (733,)
# (2038,)
# (1055,)
# (888,)
# (653,)
# (881,)
# (830,)
# (871,)

# %%
#Installing Librosa Library for creating spectrogram
# !pip install librosa
import librosa
import librosa.display
import numpy as np
# Out:
# Requirement already satisfied: librosa in c:\users\anush\anaconda3\lib\site-packages (0.10.0.post2)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (3.0.0)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.21.6)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (0.3.5)
# Requirement already satisfied: msgpack>=1.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.0.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (4.3.0)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.9.1)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (0.55.1)
# Requirement already satisfied: pooch<1.7,>=1.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (0.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\anush\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.38.0)
# Requirement already satisfied: setuptools in c:\users\anush\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (63.4.1)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\anush\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\anush\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (21.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\anush\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (2.27.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anush\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\anush\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\anush\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\anush\anaconda3\lib\site-packages (from packaging>=20.0->pooch<1.7,>=1.0->librosa) (3.0.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\anush\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anush\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\anush\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anush\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2022.9.14)

# %%
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt

# Padding the loudness arrays to be of the same length 
max_length = max(len(arr) for arr in loud_max_seg)
padded_loud_max_seg = []
for arr in loud_max_seg:
    padded_arr = np.pad(arr, (0, max_length - len(arr)), mode='constant')
    padded_loud_max_seg.append(padded_arr)
concatenated_loudness = np.vstack(padded_loud_max_seg)

# Standardization (Z-score normalization)
mean_val = np.mean(concatenated_loudness)
std_val = np.std(concatenated_loudness)
scaled_loudness = (concatenated_loudness - mean_val) / std_val

sr= 22050

# Computing the spectrogram using librosa
spec = librosa.feature.melspectrogram(y=None, sr=sr, S=scaled_loudness, n_fft=2048, hop_length=512, n_mels=128)

# Converting the power spectrogram to dB scale
spec_db = librosa.power_to_db(spec, ref=np.max)

# Plotting the spectrogram
plt.figure(figsize=(10, 5))
librosa.display.specshow(spec_db, x_axis='time', y_axis='mel', sr=sr, hop_length=512, cmap='coolwarm')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel-frequency Loudness Spectrogram for Latin Genre')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.show()
