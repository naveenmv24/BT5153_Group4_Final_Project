# %%
import pandas as pd
import numpy as np
import hdf5_getters as hd
import glob
import sklearn
from sklearn import preprocessing

# %%
#To see if all the 10,000 files are available for data extraction
h5_dir = "MillionSongSubset" #<file_path where the song_dataset is stored>

# Get a list of all .h5 files in the directory and its subdirectories
h5_files = glob.glob(h5_dir + '/**/*.h5', recursive=True)
len(h5_files) #should be 10,000
# Out:
# 10000

# %%
#Reading the dataset
df = pd.read_csv("3593_song_newfeatures_genre_dataset.csv")

# %%
#Filtering out data for Pop_Rock genre 
df_song = df[df['genre'] == 'Pop_Rock']
df_song
# Out:
#       Unnamed: 0                  id  spectral_centroid_mean  \
# 0              0  TRBGMOG128F92D75BD                  10.300
# 3              3  TRBGMAZ12903CC3707                   8.497
# 4              4  TRBGWQG128F92FB42D                  17.040
# 5              5  TRBGWGD128F42418B2                  11.570
# 6              6  TRBGWVI128E0788AE7                   8.621
# ...          ...                 ...                     ...
# 3583        3583  TRAYXBC128F427FDDB                  11.360
# 3585        3585  TRAYKHZ128F145289F                   6.628
# 3586        3586  TRAYKZI128F932B9E8                   9.591
# 3587        3587  TRAYYGG128F1483C70                   5.074
# 3588        3588  TRAYYKO128F92E133B                  13.790
#
#       spectral_centroid_dev  rolloff_point_mean  rolloff_point_dev  flux_mean  \
# 0                     5.086             0.07343            0.04854   0.005130
# 3                     6.651             0.05459            0.05239   0.001664
# 4                     9.340             0.12220            0.06633   0.001189
# 5                     6.419             0.09115            0.05315   0.005204
# 6                     4.299             0.06662            0.04000   0.004621
# ...                     ...                 ...                ...        ...
# 3583                  5.920             0.09256            0.05576   0.007537
# 3585                  2.601             0.03978            0.01915   0.000188
# 3586                  4.883             0.07278            0.04677   0.007878
# 3587                  4.802             0.03178            0.04247   0.004475
# 3588                 12.040             0.10250            0.09244   0.005381
#
#       flux_dev  variability_mean  variability_dev  compactness_mean  \
# 0     0.005431          0.006496         0.002364            1591.0
# 3     0.002623          0.004215         0.002799            1665.0
# 4     0.001648          0.002966         0.001333            1629.0
# 5     0.004266          0.005861         0.002050            1586.0
# 6     0.004226          0.006753         0.001961            1602.0
# ...        ...               ...              ...               ...
# 3583  0.006075          0.007154         0.002650            1504.0
# 3585  0.000247          0.001407         0.000708            1666.0
# 3586  0.007189          0.007579         0.002482            1562.0
# 3587  0.007547          0.005746         0.002875            1704.0
# 3588  0.008489          0.005801         0.003231            1655.0
#
#       compactness_dev  rms_mean  rms_dev  low_energy_window_mean  \
# 0               186.8   0.25350  0.07534                  0.5768
# 3               270.7   0.16070  0.10290                  0.5712
# 4               201.1   0.11990  0.05009                  0.5820
# 5               195.0   0.23030  0.06744                  0.5299
# 6               195.0   0.25920  0.06310                  0.5772
# ...               ...       ...      ...                     ...
# 3583            282.6   0.27640  0.08168                  0.5450
# 3585            199.2   0.05365  0.02615                  0.5450
# 3586            187.4   0.28990  0.07315                  0.5739
# 3587            233.2   0.21610  0.09806                  0.5612
# 3588            242.8   0.21930  0.09493                  0.5465
#
#       low_energy_window_dev  zero_crossing_mean  zero_crossing_dev  \
# 0                   0.06054               32.60             13.100
# 3                   0.07137               24.18             17.220
# 4                   0.06728               46.94             18.850
# 5                   0.05519               35.59             14.350
# 6                   0.04652               26.10             11.210
# ...                     ...                 ...                ...
# 3583                0.04607               38.17             13.610
# 3585                0.04109               16.45              7.089
# 3586                0.04242               32.61             12.080
# 3587                0.05679               17.05             13.510
# 3588                0.07568               39.00             25.920
#
#                              title     genre
# 0         b'Kicking And Screaming'  Pop_Rock
# 3            b"L'idole des femmes"  Pop_Rock
# 4                 b'Take The Time'  Pop_Rock
# 5             b'When Rules Change'  Pop_Rock
# 6                       b'Hold On'  Pop_Rock
# ...                            ...       ...
# 3583                    b'Forever'  Pop_Rock
# 3585                   b'Caviglia'  Pop_Rock
# 3586  b"We're Always Losing Blood"  Pop_Rock
# 3587           b'These Four Walls'  Pop_Rock
# 3588           b"Baltech's Lament"  Pop_Rock
#
# [1919 rows x 20 columns]

# %%
#Creating lists of Genre and Track_id
track_id = df_song['id'].tolist()
genre = df_song['genre'].tolist()

# %%
genre
# Out:
# ['Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  'Pop_Rock',
#  ...]

# %%
#Function to extract the cleaned track_id
def clean(text):
    text = str(text)
    text = text.replace("b'", "")
    text = text[:-1]
    return text

# %%
#Collecting segment info for Loudness only for those songs in the 3953_dataset
batch_size = 10

song_id = []
loud_max_seg = []
pitch_seg = []
timbre_seg = []

for i in range(0, len(h5_files), batch_size):
    # Get the batch of files
    batch_files = h5_files[i:i+batch_size]
    
    # Loop through the files in the batch
    for file_name in batch_files:
        h5 = hd.open_h5_file_read(file_name)
        
        id = hd.get_track_id(h5)
        id = clean(id)

        if id in track_id:
            #print("Collecting data")
            song_id.append(hd.get_track_id(h5))
            loud_max_seg.append(hd.get_segments_loudness_max(h5))
            timbre_seg.append(hd.get_segments_timbre(h5))
            pitch_seg.append(hd.get_segments_pitches(h5))
        
        h5.close()

# %%
#All are equal to the number of songs filtered out from the Pop_rock genre
len(song_id), len(loud_max_seg), len(timbre_seg), len(pitch_seg), len(genre)
# Out:
# (1919, 1919, 1919, 1919, 1919)

# %%
#Inspecting values of loudness for different segments for 2 songs.
loud_max_seg[0:2]
# Out:
# [array([-60.   , -14.269, -10.165, -18.098, -19.136, -18.957, -10.574,
#         -17.45 , -18.35 , -15.193,  -6.984, -18.211, -10.277, -11.401,
#         -10.95 ,  -9.913, -18.137,  -8.455, -14.42 , -13.804, -17.391,
#          -8.88 , -12.917, -14.225, -17.384,  -7.533,  -8.083, -10.908,
#         -13.267, -15.265, -16.693, -18.962, -16.484, -15.335, -12.321,
#          -8.873, -14.491,  -8.149, -12.235, -11.791, -10.582, -15.997,
#          -9.895,  -9.425,  -8.333, -12.211, -12.821,  -9.517, -17.407,
#         -16.941, -19.848,  -8.06 , -20.33 , -19.079, -11.224,  -8.67 ,
#          -8.122,  -7.397, -13.993, -12.636, -15.498,  -9.211, -15.785,
#         -14.643, -18.192,  -9.677, -16.622, -15.764, -10.616,  -8.244,
#          -7.568,  -9.493,  -7.569, -12.348,  -9.815, -13.956,  -8.493,
#         -15.35 , -12.581, -19.608, -10.132, -19.459, -14.786,  -8.017,
# (699,)
# (1628,)
# (600,)
# (828,)
# (719,)
# (434,)
# (1565,)
# (594,)
# (979,)
# (825,)
# (742,)
# (642,)
# (504,)
# (647,)
# (1287,)
# (723,)
# (888,)
# (192,)
# (324,)
# (1036,)
# (865,)
# (924,)
# (1039,)
# (690,)
# (792,)
# (603,)
# (347,)
# (2756,)
# (766,)
# (581,)
# (1097,)
# (1565,)
# (1151,)
# (460,)
# (772,)
# (497,)
# (835,)
# (524,)
# (573,)
# (1118,)
# (714,)
# (1345,)
# (890,)
# (1022,)
# (1024,)
# (539,)
# (638,)
# (727,)
# (763,)
# (860,)
# (115,)
# (1332,)
# (777,)
# (551,)
# (1018,)
# (732,)
# (868,)
# (875,)
# (702,)
# (584,)
# (834,)
# (1259,)
# (995,)
# (588,)
# (725,)
# (629,)
# (830,)
# (824,)
# (733,)
# (274,)
# (2354,)
# (403,)
# (1203,)
# (831,)
# (1109,)
# (333,)
# (1053,)
# (1049,)
# (782,)
# (676,)
# (692,)
# (533,)
# (499,)
# (155,)
# (571,)
# (805,)
# (803,)
# (818,)
# (1034,)
# (773,)
# (678,)
# (574,)
# (898,)
# (978,)
# (490,)
# (1076,)
# (706,)
# (439,)
# (850,)
# (418,)
# (449,)
# (664,)
# (1219,)
# (1394,)
# (3691,)
# (730,)
# (842,)
# (471,)
# (904,)
# (633,)
# (790,)
# (915,)
# (1080,)
# (886,)
# (437,)
# (1148,)
# (550,)
# (1649,)
# (526,)
# (434,)
# (557,)
# (671,)
# (828,)
# (818,)
# (801,)
# (1047,)
# (1082,)
# (555,)
# (637,)
# (1766,)
# (667,)
# (794,)
# (790,)
# (660,)
# (717,)
# (773,)
# (362,)
# (774,)
# (1499,)
# (917,)
# (870,)
# (523,)
# (780,)
# (678,)
# (711,)
# (498,)
# (657,)
# (1163,)
# (1057,)
# (957,)
# (80,)
# (843,)
# (482,)
# (2484,)
# (712,)
# (458,)
# (1030,)
# (696,)
# (609,)
# (958,)
# (1158,)
# (736,)
# (763,)
# (708,)
# (1113,)
# (1159,)
# (788,)
# (753,)
# (850,)
# (719,)
# (889,)
# (501,)
# (902,)
# (488,)
# (415,)
# (670,)
# (573,)
# (1052,)
# (786,)
# (620,)
# (763,)
# (1354,)
# (590,)
# (740,)
# (645,)
# (763,)
# (398,)
# (1072,)
# (1324,)
# (434,)
# (365,)
# (518,)
# (405,)
# (520,)
# (966,)
# (663,)
# (742,)
# (647,)
# (721,)
# (878,)
# (718,)
# (1291,)
# (625,)
# (780,)
# (546,)
# (590,)
# (527,)
# (917,)
# (686,)
# (1528,)
# (466,)
# (677,)
# (696,)
# (593,)
# (283,)
# (738,)
# (391,)
# (929,)
# (1092,)
# (527,)
# (446,)
# (1181,)
# (773,)
# (543,)
# (758,)
# (1139,)
# (353,)
# (692,)
# (1209,)
# (356,)
# (878,)
# (601,)
# (550,)
# (737,)
# (776,)
# (759,)
# (870,)
# (1560,)
# (808,)
# (490,)
# (292,)
# (512,)
# (1282,)
# (879,)
# (883,)
# (835,)
# (773,)
# (1273,)
# (1159,)
# (592,)
# (3272,)
# (784,)
# (559,)
# (808,)
# (863,)
# (718,)
# (990,)
# (737,)
# (863,)
# (937,)
# (1016,)
# (420,)
# (1600,)
# (608,)
# (512,)
# (1117,)
# (827,)
# (921,)
# (600,)
# (695,)
# (614,)
# (1822,)
# (407,)
# (1042,)
# (1090,)
# (797,)
# (729,)
# (1290,)
# (726,)
# (1067,)
# (644,)
# (792,)
# (591,)
# (648,)
# (951,)
# (468,)
# (649,)
# (744,)
# (489,)
# (507,)
# (510,)
# (1474,)
# (417,)
# (527,)
# (1038,)
# (1085,)
# (984,)
# (158,)
# (104,)
# (693,)
# (764,)
# (548,)
# (680,)
# (661,)
# (705,)
# (690,)
# (749,)
# (1090,)
# (552,)
# (1093,)
# (576,)
# (900,)
# (797,)
# (710,)
# (757,)
# (604,)
# (1036,)
# (241,)
# (1393,)
# (485,)
# (588,)
# (839,)
# (401,)
# (815,)
# (357,)
# (747,)
# (488,)
# (1046,)
# (665,)
# (399,)
# (2602,)
# (208,)
# (1061,)
# (793,)
# (1439,)
# (1167,)
# (634,)
# (940,)
# (1348,)
# (543,)
# (441,)
# (13,)
# (1176,)
# (933,)
# (866,)
# (525,)
# (607,)
# (1352,)
# (506,)
# (323,)
# (559,)
# (1505,)
# (1128,)
# (725,)
# (1555,)
# (1161,)
# (707,)
# (1901,)
# (958,)
# (273,)
# (452,)
# (682,)
# (542,)
# (543,)
# (90,)
# (840,)
# (949,)
# (790,)
# (303,)
# (1015,)
# (1232,)
# (783,)
# (1112,)
# (807,)
# (758,)
# (807,)
# (728,)
# (542,)
# (887,)
# (401,)
# (1044,)
# (769,)
# (797,)
# (985,)
# (471,)
# (596,)
# (476,)
# (588,)
# (712,)
# (675,)
# (435,)
# (988,)
# (927,)
# (861,)
# (1278,)
# (318,)
# (526,)
# (949,)
# (1386,)
# (1011,)
# (1756,)
# (538,)
# (606,)
# (729,)
# (800,)
# (626,)
# (485,)
# (109,)
# (953,)
# (429,)
# (1152,)
# (673,)
# (588,)
# (1224,)
# (739,)
# (458,)
# (799,)
# (574,)
# (1468,)
# (734,)
# (579,)
# (804,)
# (664,)
# (572,)
# (1054,)
# (625,)
# (789,)
# (530,)
# (453,)
# (971,)
# (605,)
# (1175,)
# (742,)
# (435,)
# (462,)
# (837,)
# (465,)
# (2297,)
# (363,)
# (857,)
# (977,)
# (503,)
# (1074,)
# (303,)
# (773,)
# (676,)
# (621,)
# (769,)
# (652,)
# (364,)
# (1217,)
# (502,)
# (599,)
# (940,)
# (807,)
# (119,)
# (623,)
# (376,)
# (530,)
# (446,)
# (605,)
# (961,)
# (640,)
# (1296,)
# (789,)
# (300,)
# (436,)
# (854,)
# (973,)
# (806,)
# (1177,)
# (522,)
# (802,)
# (1170,)
# (714,)
# (653,)
# (672,)
# (1011,)
# (673,)
# (991,)
# (690,)
# (572,)
# (650,)
# (742,)
# (949,)
# (983,)
# (935,)
# (1227,)
# (492,)
# (487,)
# (467,)
# (616,)
# (1089,)
# (1066,)
# (653,)
# (276,)
# (673,)
# (1196,)
# (822,)
# (993,)
# (662,)
# (913,)
# (2868,)
# (966,)
# (504,)
# (481,)
# (635,)
# (757,)
# (1329,)
# (993,)
# (510,)
# (849,)
# (1918,)
# (969,)
# (1068,)
# (536,)
# (1037,)
# (458,)
# (954,)
# (1015,)
# (1987,)
# (1562,)
# (420,)
# (405,)
# (1427,)
# (971,)
# (1109,)
# (861,)
# (655,)
# (645,)
# (180,)
# (1144,)
# (453,)
# (727,)
# (567,)
# (686,)
# (567,)
# (746,)
# (560,)
# (117,)
# (579,)
# (896,)
# (643,)
# (492,)
# (777,)
# (856,)
# (231,)
# (755,)
# (1231,)
# (692,)
# (623,)
# (168,)
# (824,)
# (681,)
# (1144,)
# (722,)
# (678,)
# (685,)
# (1144,)
# (592,)
# (536,)
# (646,)
# (1046,)
# (1016,)
# (1014,)
# (732,)
# (892,)
# (418,)
# (598,)
# (482,)
# (457,)
# (418,)
# (144,)
# (623,)
# (853,)
# (745,)
# (608,)
# (465,)
# (869,)
# (1032,)
# (718,)
# (1120,)
# (500,)
# (461,)
# (469,)
# (971,)
# (613,)
# (705,)
# (562,)
# (103,)
# (187,)
# (868,)
# (579,)
# (902,)
# (383,)
# (725,)
# (729,)
# (853,)
# (386,)
# (1082,)
# (652,)
# (687,)
# (645,)
# (659,)
# (810,)
# (1122,)
# (345,)
# (515,)
# (1031,)
# (1400,)
# (1050,)
# (1041,)
# (493,)
# (607,)
# (820,)
# (845,)
# (765,)
# (1107,)
# (562,)
# (418,)
# (576,)
# (1572,)
# (781,)
# (480,)
# (600,)
# (649,)
# (840,)
# (1374,)
# (597,)
# (886,)
# (822,)
# (600,)
# (722,)
# (839,)
# (914,)
# (691,)
# (1253,)
# (860,)
# (669,)
# (364,)
# (963,)
# (753,)
# (186,)
# (1009,)
# (702,)
# (698,)
# (419,)
# (891,)
# (1145,)
# (606,)
# (1039,)
# (814,)
# (411,)
# (343,)
# (598,)
# (589,)
# (984,)
# (451,)
# (1316,)
# (757,)
# (425,)
# (221,)
# (843,)
# (825,)
# (639,)
# (801,)
# (799,)
# (739,)
# (302,)
# (874,)
# (935,)
# (1298,)
# (999,)
# (566,)
# (529,)
# (970,)
# (864,)
# (1215,)
# (1164,)
# (588,)
# (500,)
# (777,)
# (586,)
# (794,)
# (887,)
# (1044,)
# (707,)
# (444,)
# (579,)
# (984,)
# (582,)
# (518,)
# (622,)
# (570,)
# (399,)
# (762,)
# (1143,)
# (760,)
# (796,)
# (774,)
# (2892,)
# (651,)
# (688,)
# (1001,)
# (804,)
# (886,)
# (699,)
# (544,)
# (819,)
# (804,)
# (669,)
# (599,)
# (695,)
# (701,)
# (691,)
# (635,)
# (455,)
# (864,)
# (948,)
# (701,)
# (1042,)
# (679,)
# (923,)
# (681,)
# (497,)
# (532,)
# (729,)
# (969,)
# (1160,)
# (392,)
# (832,)
# (880,)
# (2224,)
# (907,)
# (1061,)
# (738,)
# (600,)
# (816,)
# (710,)
# (672,)
# (1362,)
# (715,)
# (777,)
# (648,)
# (473,)
# (882,)
# (1004,)
# (732,)
# (469,)
# (611,)
# (799,)
# (648,)
# (513,)
# (597,)
# (371,)
# (1199,)
# (1323,)
# (854,)
# (494,)
# (696,)
# (1136,)
# (613,)
# (1044,)
# (864,)
# (257,)
# (697,)
# (1518,)
# (1817,)
# (937,)
# (462,)
# (622,)
# (751,)
# (104,)
# (874,)
# (767,)
# (525,)
# (1953,)
# (808,)
# (898,)
# (640,)
# (655,)
# (761,)
# (524,)
# (924,)
# (1298,)
# (712,)
# (2068,)
# (884,)
# (280,)
# (581,)
# (529,)
# (1007,)
# (871,)
# (482,)
# (1098,)
# (763,)
# (609,)
# (345,)
# (941,)
# (333,)
# (397,)
# (1055,)
# (931,)
# (885,)
# (429,)
# (617,)
# (458,)
# (746,)
# (737,)
# (889,)
# (817,)
# (718,)
# (780,)
# (895,)
# (946,)
# (1216,)
# (827,)
# (629,)
# (371,)
# (499,)
# (807,)
# (680,)
# (1343,)
# (735,)
# (1000,)
# (344,)
# (370,)
# (475,)
# (705,)
# (593,)
# (669,)
# (810,)
# (660,)
# (960,)
# (694,)
# (680,)
# (853,)
# (158,)
# (917,)
# (221,)
# (266,)
# (1089,)
# (966,)
# (506,)
# (1329,)
# (463,)
# (905,)
# (1150,)
# (2649,)
# (472,)
# (609,)
# (949,)
# (811,)
# (722,)
# (956,)
# (123,)
# (854,)
# (775,)
# (149,)
# (826,)
# (407,)
# (646,)
# (987,)
# (1526,)
# (1191,)
# (805,)
# (636,)
# (912,)
# (287,)
# (614,)
# (618,)
# (645,)
# (1378,)
# (952,)
# (758,)
# (777,)
# (205,)
# (917,)
# (960,)
# (167,)
# (216,)
# (170,)
# (666,)
# (834,)
# (677,)
# (978,)
# (445,)
# (738,)
# (685,)
# (749,)
# (457,)
# (619,)
# (598,)
# (378,)
# (596,)
# (614,)
# (707,)
# (977,)
# (584,)
# (2364,)
# (644,)
# (748,)
# (1130,)
# (1827,)
# (423,)
# (230,)
# (156,)
# (927,)
# (849,)
# (1119,)
# (625,)
# (276,)
# (534,)
# (526,)
# (473,)
# (737,)
# (492,)
# (662,)
# (666,)
# (443,)
# (763,)
# (526,)
# (1121,)
# (588,)
# (1029,)
# (883,)
# (890,)
# (699,)
# (724,)
# (700,)
# (724,)
# (685,)
# (260,)
# (891,)
# (184,)
# (435,)
# (674,)
# (838,)
# (1364,)
# (939,)
# (1158,)
# (733,)
# (1111,)
# (835,)
# (909,)
# (567,)
# (1089,)
# (778,)
# (664,)
# (1046,)
# (831,)
# (811,)
# (749,)
# (950,)
# (467,)
# (459,)
# (1172,)
# (707,)
# (1159,)
# (620,)
# (928,)
# (549,)
# (581,)
# (400,)
# (853,)
# (1001,)
# (158,)
# (625,)
# (418,)
# (478,)
# (1038,)
# (1436,)
# (1279,)
# (360,)
# (912,)
# (542,)
# (747,)
# (770,)
# (1165,)
# (1117,)
# (284,)
# (532,)
# (1025,)
# (366,)
# (734,)
# (813,)
# (643,)
# (885,)
# (1443,)
# (664,)
# (797,)
# (569,)
# (552,)
# (477,)
# (300,)
# (413,)
# (445,)
# (516,)
# (669,)
# (1014,)
# (948,)
# (500,)
# (774,)
# (976,)
# (807,)
# (549,)
# (787,)
# (1141,)
# (843,)
# (484,)
# (616,)
# (1034,)
# (575,)
# (701,)
# (821,)
# (742,)
# (1364,)
# (959,)
# (765,)
# (725,)
# (651,)
# (625,)
# (670,)
# (312,)
# (1667,)
# (819,)
# (1620,)
# (838,)
# (785,)
# (1508,)
# (1282,)
# (906,)
# (489,)
# (939,)
# (691,)
# (813,)
# (397,)
# (765,)
# (1378,)
# (642,)
# (543,)
# (497,)
# (887,)
# (583,)
# (590,)
# (867,)
# (950,)
# (476,)
# (697,)
# (782,)
# (680,)
# (656,)
# (1189,)
# (309,)
# (1036,)
# (914,)
# (399,)
# (516,)
# (493,)
# (504,)
# (426,)
# (864,)
# (988,)
# (752,)
# (729,)
# (633,)
# (845,)
# (435,)
# (153,)
# (501,)
# (368,)
# (931,)
# (353,)
# (773,)
# (248,)
# (556,)
# (1455,)
# (714,)
# (590,)
# (731,)
# (867,)
# (522,)
# (595,)
# (854,)
# (1689,)
# (732,)
# (427,)
# (1186,)
# (890,)
# (511,)
# (2531,)
# (987,)
# (686,)
# (971,)
# (826,)
# (673,)
# (651,)
# (639,)
# (1962,)
# (657,)
# (655,)
# (1552,)
# (631,)
# (734,)
# (519,)
# (1457,)
# (654,)
# (422,)
# (3440,)
# (979,)
# (545,)
# (401,)
# (970,)
# (591,)
# (1222,)
# (961,)
# (160,)
# (500,)
# (744,)
# (807,)
# (779,)
# (959,)
# (469,)
# (504,)
# (511,)
# (665,)
# (707,)
# (780,)
# (843,)
# (595,)
# (842,)
# (921,)
# (1215,)
# (599,)
# (904,)
# (969,)
# (962,)
# (4,)
# (509,)
# (863,)
# (474,)
# (789,)
# (623,)
# (542,)
# (1013,)
# (408,)
# (613,)
# (632,)
# (896,)
# (527,)
# (1014,)
# (796,)
# (672,)
# (814,)
# (627,)
# (839,)
# (757,)
# (1076,)
# (383,)
# (349,)
# (904,)
# (500,)
# (1049,)
# (566,)
# (853,)
# (1086,)
# (2416,)
# (792,)
# (733,)
# (87,)
# (846,)
# (1128,)
# (546,)
# (212,)
# (115,)
# (744,)
# (653,)
# (864,)
# (669,)
# (1001,)
# (1005,)
# (968,)
# (903,)
# (740,)
# (899,)
# (802,)
# (752,)
# (440,)
# (535,)
# (183,)
# (677,)
# (418,)
# (1841,)
# (511,)
# (613,)
# (703,)
# (929,)
# (667,)
# (486,)
# (1626,)
# (1458,)
# (1143,)
# (651,)
# (541,)
# (775,)
# (739,)
# (356,)
# (1087,)
# (561,)
# (938,)
# (520,)
# (604,)
# (729,)
# (529,)
# (407,)
# (628,)
# (553,)
# (1081,)
# (366,)
# (886,)
# (356,)
# (1297,)
# (609,)
# (483,)
# (771,)
# (452,)
# (794,)
# (712,)
# (767,)
# (1192,)
# (1488,)
# (998,)
# (139,)
# (345,)
# (637,)
# (877,)
# (907,)
# (1312,)
# (828,)
# (1156,)
# (174,)
# (835,)
# (943,)
# (614,)
# (205,)
# (990,)
# (1063,)
# (540,)
# (616,)
# (604,)
# (731,)
# (473,)
# (998,)
# (1065,)
# (517,)
# (797,)
# (773,)
# (786,)
# (1041,)
# (2741,)
# (675,)
# (682,)
# (193,)
# (710,)
# (1080,)
# (470,)
# (207,)
# (1024,)
# (1538,)
# (674,)
# (870,)
# (687,)
# (579,)
# (1341,)
# (805,)
# (733,)
# (486,)
# (664,)
# (880,)
# (1869,)
# (1036,)
# (699,)
# (709,)
# (873,)
# (481,)
# (685,)
# (744,)
# (429,)
# (686,)
# (272,)
# (658,)
# (1068,)
# (541,)
# (1936,)
# (596,)
# (814,)
# (799,)
# (704,)
# (213,)
# (292,)
# (624,)
# (930,)
# (318,)
# (1883,)
# (569,)
# (821,)
# (684,)
# (531,)
# (569,)
# (767,)
# (192,)
# (1325,)
# (902,)
# (946,)
# (725,)
# (94,)
# (281,)
# (663,)
# (799,)
# (585,)
# (767,)
# (616,)
# (584,)
# (732,)
# (241,)
# (855,)
# (740,)
# (1059,)
# (616,)
# (254,)
# (169,)
# (541,)
# (818,)
# (480,)
# (793,)
# (191,)
# (654,)
# (491,)
# (702,)
# (1177,)
# (769,)
# (445,)
# (391,)
# (749,)
# (1163,)
# (572,)
# (714,)
# (844,)
# (687,)
# (1574,)
# (555,)
# (581,)
# (914,)
# (215,)
# (967,)
# (822,)
# (626,)
# (939,)
# (857,)
# (170,)
# (511,)
# (832,)
# (1785,)
# (857,)
# (1538,)
# (697,)
# (674,)
# (509,)
# (453,)
# (974,)
# (733,)
# (608,)
# (615,)
# (500,)
# (378,)
# (374,)
# (673,)
# (1235,)
# (676,)
# (661,)
# (793,)
# (745,)
# (449,)
# (941,)
# (1100,)
# (954,)
# (780,)
# (712,)
# (589,)
# (557,)
# (866,)
# (386,)
# (334,)
# (611,)
# (950,)
# (663,)
# (510,)
# (652,)
# (1096,)
# (516,)
# (869,)
# (589,)
# (170,)
# (553,)
# (587,)
# (687,)
# (1079,)
# (669,)
# (373,)
# (665,)
# (1365,)
# (862,)
# (231,)
# (739,)
# (1096,)
# (537,)
# (719,)
# (688,)
# (665,)
# (844,)
# (435,)
# (471,)
# (615,)
# (864,)
# (620,)
# (922,)
# (1035,)
# (1850,)
# (768,)
# (408,)
# (771,)
# (581,)
# (504,)
# (1038,)
# (670,)
# (513,)
# (512,)
# (703,)
# (990,)
# (1195,)
# (870,)
# (1032,)
# (832,)
# (890,)
# (456,)
# (534,)
# (727,)
# (895,)
# (696,)
# (567,)
# (632,)
# (690,)
# (468,)
# (799,)
# (602,)
# (2695,)
# (562,)
# (1082,)
# (885,)
# (908,)
# (735,)
# (283,)
# (919,)
# (843,)
# (633,)
# (1201,)
# (580,)
# (797,)
# (560,)
# (385,)
# (753,)
# (666,)
# (559,)
# (719,)
# (425,)
# (948,)
# (780,)
# (525,)
# (1677,)
# (617,)
# (813,)
# (676,)
# (778,)
# (509,)
# (697,)
# (689,)
# (659,)
# (1054,)
# (813,)
# (394,)
# (709,)
# (186,)
# (631,)
# (705,)
# (444,)
# (799,)
# (579,)
# (722,)
# (396,)
# (969,)
# (1126,)
# (840,)
# (979,)
# (930,)
# (568,)
# (316,)
# (718,)
# (755,)
# (692,)
# (612,)
# (840,)
# (944,)
# (999,)
# (973,)
# (1053,)
# (687,)
# (1286,)
# (783,)
# (1734,)
# (594,)
# (774,)
# (675,)
# (1227,)
# (987,)
# (1021,)
# (154,)
# (1271,)
# (1015,)
# (794,)
# (870,)
# (713,)
# (729,)
# (1333,)
# (849,)
# (567,)
# (613,)
# (783,)
# (900,)
# (345,)
# (1010,)
# (917,)
# (1140,)
# (458,)
# (814,)
# (752,)
# (671,)
# (841,)
# (930,)
# (856,)
# (630,)
# (342,)
# (965,)
# (360,)
# (746,)
# (755,)
# (856,)
# (1008,)
# (664,)
# (1235,)
# (848,)
# (546,)
# (609,)
# (880,)
# (983,)
# (479,)
# (801,)
# (700,)
# (1982,)
# (415,)
# (454,)
# (667,)
# (887,)
# (774,)
# (772,)
# (699,)
# (628,)
# (1382,)
# (510,)
# (407,)
# (799,)
# (401,)
# (566,)
# (855,)
# (348,)
# (290,)
# (868,)
# (456,)
# (1090,)
# (315,)
# (644,)
# (607,)
# (590,)
# (1060,)
# (779,)
# (705,)
# (724,)
# (800,)
# (881,)
# (1030,)
# (1074,)
# (596,)
# (370,)
# (1144,)
# (845,)
# (588,)
# (620,)
# (740,)
# (730,)
# (1411,)
# (1069,)
# (709,)
# (933,)
# (759,)
# (440,)
# (525,)
# (936,)
# (280,)
# (764,)
# (486,)
# (1412,)
# (623,)
# (393,)
# (414,)
# (1100,)
# (602,)
# (1016,)
# (818,)
# (777,)
# (684,)
# (375,)
# (316,)
# (563,)
# (1298,)
# (554,)
# (486,)
# (842,)
# (2338,)
# (580,)
# (885,)
# (981,)
# (11,)
# (632,)
# (1052,)
# (483,)
# (600,)
# (659,)
# (827,)
# (1010,)
# (591,)
# (639,)
# (570,)
# (870,)
# (2337,)
# (936,)
# (457,)
# (726,)
# (1172,)
# (1078,)
# (526,)
# (688,)
# (414,)
# (708,)
# (782,)
# (778,)
# (969,)
# (676,)
# (841,)
# (768,)
# (401,)
# (803,)
# (731,)
# (1119,)
# (527,)
# (909,)
# (602,)
# (1003,)
# (1011,)
# (832,)
# (739,)
# (587,)
# (715,)
# (353,)
# (1245,)
# (656,)
# (1609,)
# (63,)
# (661,)
# (814,)
# (1443,)
# (746,)
# (656,)
# (129,)
# (539,)
# (761,)
# (506,)
# (677,)
# (601,)
# (967,)
# (717,)
# (538,)
# (635,)
# (1140,)
# (704,)
# (663,)
# (987,)
# (1006,)
# (655,)
# (569,)
# (758,)
# (574,)
# (709,)
# (673,)
# (1644,)
# (616,)
# (607,)
# (820,)
# (639,)
# (1002,)
# (680,)
# (791,)
# (622,)
# (965,)
# (595,)
# (649,)
# (2499,)
# (961,)
# (769,)
# (524,)
# (618,)
# (82,)
# (2082,)
# (647,)
# (1058,)
# (713,)
# (1093,)
# (148,)
# (595,)
# (257,)
# (1191,)
# (331,)
# (661,)
# (530,)
# (944,)
# (838,)
# (710,)
# (1424,)
# (449,)
# (709,)
# (802,)
# (697,)
# (957,)
# (282,)
# (1180,)
# (466,)
# (357,)
# (766,)
# (803,)
# (775,)
# (725,)
# (744,)
# (732,)
# (725,)
# (696,)
# (591,)
# (462,)
# (1291,)
# (517,)
# (1639,)
# (87,)
# (706,)
# (767,)
# (498,)
# (484,)
# (1577,)
# (636,)
# (487,)
# (911,)
# (820,)
# (711,)
# (624,)
# (864,)
# (688,)
# (2476,)
# (826,)
# (672,)
# (629,)
# (1091,)
# (873,)
# (217,)
# (898,)
# (1122,)
# (989,)
# (580,)
# (472,)
# (393,)
# (96,)
# (811,)
# (2103,)
# (467,)
# (226,)
# (357,)
# (1098,)
# (193,)
# (1713,)
# (594,)
# (662,)
# (683,)
# (493,)
# (524,)
# (1039,)
# (833,)
# (715,)
# (1032,)
# (414,)
# (1013,)
# (489,)
# (721,)
# (646,)
# (579,)
# (1354,)
# (720,)
# (1841,)
# (1196,)
# (762,)
# (486,)
# (843,)
# (938,)
# (1004,)
# (624,)
# (829,)
# (984,)
# (1515,)
# (857,)
# (699,)
# (237,)
# (596,)
# (1147,)
# (755,)
# (427,)
# (1142,)
# (741,)
# (1007,)
# (791,)
# (543,)
# (1111,)
# (545,)
# (639,)
# (813,)
# (879,)
# (1029,)
# (420,)
# (980,)
# (663,)
# (931,)
# (55,)
# (308,)
# (1219,)
# (433,)
# (781,)
# (3634,)
# (344,)
# (702,)
# (801,)
# (1028,)
# (643,)
# (1084,)
# (640,)
# (494,)
# (1061,)
# (982,)
# (62,)
# (601,)
# (559,)
# (799,)
# (631,)
# (804,)
# (706,)
# (683,)
# (761,)
# (591,)
# (601,)
# (559,)
# (559,)
# (1532,)
# (2506,)
# (558,)
# (699,)
# (469,)
# (445,)
# (308,)
# (893,)
# (1109,)
# (572,)
# (1280,)
# (858,)
# (648,)
# (912,)
# (607,)
# (630,)
# (690,)
# (688,)
# (809,)
# (1038,)
# (473,)
# (678,)
# (920,)
# (557,)
# (529,)
# (538,)
# (1049,)
# (792,)
# (511,)
# (672,)
# (395,)
# (611,)

# %%
#Installing Librosa Library for creating spectrogram
# !pip install librosa
import librosa
import librosa.display
import numpy as np
# Out:
# Requirement already satisfied: librosa in c:\users\anush\anaconda3\lib\site-packages (0.10.0.post2)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (4.3.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.0.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (0.2)
# Requirement already satisfied: msgpack>=1.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: numba>=0.51.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (0.55.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.21.6)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.9.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (3.0.0)
# Requirement already satisfied: joblib>=0.14 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: pooch<1.7,>=1.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (0.3.5)
# Requirement already satisfied: setuptools in c:\users\anush\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (63.4.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\anush\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\anush\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (21.3)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\anush\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\anush\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (2.27.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anush\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\anush\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\anush\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\anush\anaconda3\lib\site-packages (from packaging>=20.0->pooch<1.7,>=1.0->librosa) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anush\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anush\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\anush\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (1.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\anush\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2.0.4)

# %%
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt

# Padding the loudness arrays to be of the same length 
max_length = max(len(arr) for arr in loud_max_seg)
padded_loud_max_seg = []
for arr in loud_max_seg:
    padded_arr = np.pad(arr, (0, max_length - len(arr)), mode='constant')
    padded_loud_max_seg.append(padded_arr)
concatenated_loudness = np.vstack(padded_loud_max_seg)

# Standardization (Z-score normalization)
mean_val = np.mean(concatenated_loudness)
std_val = np.std(concatenated_loudness)
scaled_loudness = (concatenated_loudness - mean_val) / std_val

sr= 22050

# Computing the spectrogram using librosa
spec = librosa.feature.melspectrogram(y=None, sr=sr, S=scaled_loudness, n_fft=2048, hop_length=512, n_mels=128)

# Converting the power spectrogram to dB scale
spec_db = librosa.power_to_db(spec, ref=np.max)

# Plotting the spectrogram
plt.figure(figsize=(10, 5))
librosa.display.specshow(spec_db, x_axis='time', y_axis='mel', sr=sr, hop_length=512, cmap='coolwarm')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel-frequency spectrogram for Pop Rock genre')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.show()
