# %%
import pandas as pd
import numpy as np
import hdf5_getters as hd
import glob
import sklearn
from sklearn import preprocessing

# %%
#To see if all the 10,000 files are available for data extraction
h5_dir = "MillionSongSubset" #<file_path where the song_dataset is stored>

# Get a list of all .h5 files in the directory and its subdirectories
h5_files = glob.glob(h5_dir + '/**/*.h5', recursive=True)
len(h5_files) #should be 10,000
# Out:
# 10000

# %%
#Reading the dataset
df = pd.read_csv("3593_song_newfeatures_genre_dataset.csv")

# %%
#Filtering out data for Reggae genre 
df_song = df[df['genre'] == 'Reggae']
df_song
# Out:
#       Unnamed: 0                  id  spectral_centroid_mean  \
# 18            18  TRBGRGB128F4289283                   9.088
# 52            52  TRBGTHM128F933DBB1                  10.230
# 120          120  TRBHRGS128F92E535F                  10.330
# 145          145  TRBHNSS128F4228E6E                   8.093
# 149          149  TRBHTSP128F9307CC3                   9.702
# ...          ...                 ...                     ...
# 3397        3397  TRAKGOF128F93060F6                   6.646
# 3476        3476  TRAYMYA128F4262C9D                  11.780
# 3518        3518  TRAYZLG128F92F3BCD                  13.100
# 3534        3534  TRAYPXP12903CD8D45                   7.668
# 3569        3569  TRAYVCS12903CE1ED8                  11.830
#
#       spectral_centroid_dev  rolloff_point_mean  rolloff_point_dev  flux_mean  \
# 18                    8.234             0.05882            0.06822   0.001884
# 52                   13.650             0.06621            0.10800   0.001134
# 120                  12.850             0.07040            0.09912   0.008352
# 145                   5.341             0.04895            0.03659   0.004269
# 149                  12.960             0.06543            0.10130   0.002973
# ...                     ...                 ...                ...        ...
# 3397                  5.272             0.04085            0.04253   0.004870
# 3476                 13.360             0.08615            0.10540   0.002955
# 3518                 14.470             0.09010            0.10170   0.001416
# 3534                 11.830             0.05156            0.07661   0.002020
# 3569                  5.828             0.06456            0.03758   0.000704
#
#       flux_dev  variability_mean  variability_dev  compactness_mean  \
# 18    0.003219          0.003828         0.001985            1696.0
# 52    0.002011          0.003236         0.002291            1646.0
# 120   0.011180          0.007905         0.004260            1583.0
# 145   0.005830          0.005650         0.003574            1626.0
# 149   0.005003          0.006836         0.004576            1656.0
# ...        ...               ...              ...               ...
# 3397  0.005677          0.006902         0.003058            1630.0
# 3476  0.004042          0.004702         0.002545            1599.0
# 3518  0.001991          0.003304         0.001933            1555.0
# 3534  0.003645          0.003771         0.002417            1574.0
# 3569  0.001563          0.002181         0.002610            1549.0
#
#       compactness_dev  rms_mean  rms_dev  low_energy_window_mean  \
# 18              224.3   0.14440  0.06426                  0.5432
# 52              192.5   0.11550  0.07378                  0.5029
# 120             211.7   0.28820  0.13110                  0.4889
# 145             232.6   0.21010  0.11860                  0.5161
# 149             234.3   0.23460  0.12890                  0.4870
# ...               ...       ...      ...                     ...
# 3397            237.4   0.26030  0.09708                  0.5004
# 3476            199.1   0.17580  0.08808                  0.4372
# 3518            284.3   0.12430  0.06419                  0.5284
# 3534            233.6   0.14100  0.08352                  0.5400
# 3569            190.0   0.08301  0.09782                  0.6436
#
#       low_energy_window_dev  zero_crossing_mean  zero_crossing_dev  \
# 18                  0.04884               29.12             19.870
# 52                  0.05740               30.44             33.210
# 120                 0.06138               31.97             29.920
# 145                 0.04066               22.53             12.940
# 149                 0.06526               27.82             30.380
# ...                     ...                 ...                ...
# 3397                0.06210               19.99             14.670
# 3476                0.05047               37.41             30.110
# 3518                0.04909               36.46             30.100
# 3534                0.06323               20.55             24.550
# 3569                0.06069               24.99              7.381
#
#                                                title   genre
# 18                                 b'Over The River'  Reggae
# 52                                b'For All We Know'  Reggae
# 120                             b'Chasing Windmills'  Reggae
# 145     b'Head Gone/Wine Up Uh Self (Album Version)'  Reggae
# 149                b'In Di Car Back (Album Version)'  Reggae
# ...                                              ...     ...
# 3397                      b'Happiness Is Loving You'  Reggae
# 3476                                 b'Them No Care'  Reggae
# 3518                            b'Quest for Oneness'  Reggae
# 3534                                   b'Conquer Me'  Reggae
# 3569  b'Excerpt Of A Speech By Marcus Mosiah Garvey'  Reggae
#
# [120 rows x 20 columns]

# %%
#Creating lists of Genre and Track_id
track_id = df_song['id'].tolist()
genre = df_song['genre'].tolist()

# %%
genre
# Out:
# ['Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae',
#  'Reggae']

# %%
#Function to extract the cleaned track_id
def clean(text):
    text = str(text)
    text = text.replace("b'", "")
    text = text[:-1]
    return text

# %%
#Collecting segment info for Loudness only for those songs in the 3953_dataset
batch_size = 10

song_id = []
loud_max_seg = []
pitch_seg = []
timbre_seg = []

for i in range(0, len(h5_files), batch_size):
    # Get the batch of files
    batch_files = h5_files[i:i+batch_size]
    
    # Loop through the files in the batch
    for file_name in batch_files:
        h5 = hd.open_h5_file_read(file_name)
        
        id = hd.get_track_id(h5)
        id = clean(id)

        if id in track_id:
            #print("Collecting data")
            song_id.append(hd.get_track_id(h5))
            loud_max_seg.append(hd.get_segments_loudness_max(h5))
            timbre_seg.append(hd.get_segments_timbre(h5))
            pitch_seg.append(hd.get_segments_pitches(h5))
        
        h5.close()

# %%
#All are equal to the number of songs filtered out from the Reggae genre
len(song_id), len(loud_max_seg), len(timbre_seg), len(pitch_seg), len(genre)
# Out:
# (120, 120, 120, 120, 120)

# %%
#Inspecting values of loudness for different segments for 2 songs.
loud_max_seg[0:2]
# Out:
# [array([-19.546, -11.266, -13.553, ..., -36.49 , -39.416, -43.611]),
#  array([-58.429, -18.598, -24.699, ..., -36.504, -47.369, -52.444])]

# %%
#inspecting the segments' shape for all songs
for arr in loud_max_seg:
    print(arr.shape)
# Out:
# (1006,)
# (1151,)
# (737,)
# (1077,)
# (884,)
# (1286,)
# (1591,)
# (1038,)
# (850,)
# (133,)
# (1396,)
# (726,)
# (982,)
# (952,)
# (915,)
# (1297,)
# (1030,)
# (938,)
# (654,)
# (989,)
# (917,)
# (984,)
# (1090,)
# (1013,)
# (952,)
# (918,)
# (975,)
# (620,)
# (943,)
# (1097,)
# (660,)
# (1308,)
# (1074,)
# (1194,)
# (1349,)
# (702,)
# (811,)
# (735,)
# (965,)
# (1607,)
# (942,)
# (836,)
# (1004,)
# (1369,)
# (821,)
# (969,)
# (1251,)
# (1038,)
# (1169,)
# (969,)
# (1214,)
# (1066,)
# (649,)
# (1177,)
# (1051,)
# (762,)
# (900,)
# (1150,)
# (1050,)
# (885,)
# (756,)
# (1201,)
# (1050,)
# (850,)
# (864,)
# (1073,)
# (1190,)
# (838,)
# (906,)
# (762,)
# (614,)
# (953,)
# (897,)
# (1365,)
# (980,)
# (1508,)
# (1011,)
# (1359,)
# (1033,)
# (1129,)
# (1199,)
# (1123,)
# (1120,)
# (1581,)
# (1113,)
# (823,)
# (868,)
# (1130,)
# (831,)
# (228,)
# (829,)
# (1002,)
# (1053,)
# (1234,)
# (1268,)
# (649,)
# (336,)
# (756,)
# (867,)
# (1282,)
# (1116,)
# (948,)
# (1079,)
# (920,)
# (956,)
# (982,)
# (987,)
# (763,)
# (955,)
# (1050,)
# (842,)
# (1124,)
# (1239,)
# (2017,)
# (891,)
# (1046,)
# (1093,)
# (1222,)
# (859,)
# (836,)

# %%
#Installing Librosa Library for creating spectrogram
# !pip install librosa
import librosa
import librosa.display
import numpy as np
# Out:
# Requirement already satisfied: librosa in c:\users\anush\anaconda3\lib\site-packages (0.10.0.post2)
# Requirement already satisfied: numba>=0.51.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (0.55.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.21.6)
# Requirement already satisfied: pooch<1.7,>=1.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (4.3.0)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.9.1)
# Requirement already satisfied: joblib>=0.14 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (0.2)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (3.0.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.0.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (0.3.5)
# Requirement already satisfied: msgpack>=1.0 in c:\users\anush\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: setuptools in c:\users\anush\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (63.4.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\anush\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.38.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\anush\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (2.27.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\anush\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (21.3)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\anush\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anush\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\anush\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\anush\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\anush\anaconda3\lib\site-packages (from packaging>=20.0->pooch<1.7,>=1.0->librosa) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\anush\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (1.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\anush\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anush\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anush\anaconda3\lib\site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2.6)

# %%
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt

# Padding the loudness arrays to be of the same length 
max_length = max(len(arr) for arr in loud_max_seg)
padded_loud_max_seg = []
for arr in loud_max_seg:
    padded_arr = np.pad(arr, (0, max_length - len(arr)), mode='constant')
    padded_loud_max_seg.append(padded_arr)
concatenated_loudness = np.vstack(padded_loud_max_seg)

# Standardization (Z-score normalization)
mean_val = np.mean(concatenated_loudness)
std_val = np.std(concatenated_loudness)
scaled_loudness = (concatenated_loudness - mean_val) / std_val

sr= 22050

# Computing the spectrogram using librosa
spec = librosa.feature.melspectrogram(y=None, sr=sr, S=scaled_loudness, n_fft=2048, hop_length=512, n_mels=64)

# Converting the power spectrogram to dB scale
spec_db = librosa.power_to_db(spec, ref=np.max)

# Plotting the spectrogram
plt.figure(figsize=(10, 5))
librosa.display.specshow(spec_db, x_axis='time', y_axis='mel', sr=sr, hop_length=512, cmap='coolwarm')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel-frequency spectrogram for Reggae genre')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.show()
